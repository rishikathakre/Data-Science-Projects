# %% [markdown]
# <a href="https://colab.research.google.com/github/rishikathakre/OIBSIP/blob/main/Iris_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Name : Rishika Thakre
# ## College : P.E.S Modern College of Engineering
# ## Task 1 : Iris Flower Classification

# %% [markdown]
# # Classify the species of Iris flower i.e Setosa, Versicolor and Virgnica according to the measurement

# %% [markdown]
# ## Domain analysis

# %% [markdown]
# - SepalLengthCm : Sepal length of iris flower
# - SepalWidthCm : Sepal width of iris flower
# - PetalLengthCm : Petal length of iris flower
# - PetalWidthCm : Petal width of iris flower
# - Species : Species of iris flower

# %% [markdown]
# ## Importing Libraries and Loading Data

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#Load data
data = pd.read_csv('Iris.csv.xls')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## Basic Checks

# %%
data.shape
# Out:
# (150, 6)

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# #### Insigths
# - There are 150 rows and 6 columns in dataset
# - There is one object data type in the dataset
# - Minimum Lengths
#     - sepal length is 4.3 cm
#     - petal length is 1 cm
# - Minimum Width
#     - sepal width is 2 cm
#     - petal width is 0.1 cm
# - Maximum Lengths
#     - sepal length is 7.9 cm
#     - petal length is 6.9 cm
# - Maximum Width
#     - sepal width is 4.4 cm
#     - petal width is 2.5 cm

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ##### Univariate Analysis

# %%
import sweetviz as sv
report= sv.analyze(data)
report.show_html()
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ##### Bivariate Analysis

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in data:
    if plotnumber<=5 :
        ax = plt.subplot(3,2,plotnumber)
        sns.histplot(x=data[column],hue=data['Species'])
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Species',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ##### Multivariate Analysis

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# #### Insigth
# - Sepal Length:
#     - Setosa - From 4.3 to 5.5 cm
#     - Versicolor - From 5.5 till 6.3 cm
#     - Verginica - From 6.3 till 7.9 cm

# %% [markdown]
# ## Data Preprocessing Pipeline

# %%
# Step1 : Checking Missing Values
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Step2 : Converting Categorical to Numerical
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data['Species']=data['Species'].map({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})

# %%
# Step3 : Check Outliers
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in data:
    if plotnumber<=5 :
        ax = plt.subplot(3,2,plotnumber)
        sns.boxplot(x=data[column])
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Species',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
# Handling Outliers in SepalWidthCm
#Checking the distribution
sns.distplot(data.SepalWidthCm)
plt.show()

# %%
# Interquartile range (IQR) 
from scipy import stats

IQR = stats.iqr(data.SepalWidthCm, interpolation = 'midpoint') 

IQR
# Out:
# 0.5

# %%
## min and max limit calculation
# First quartile (Q1) 
Q1 =data.SepalWidthCm.quantile(0.25)
# Third quartile (Q3) 
Q3 =data.SepalWidthCm.quantile(0.75)
##getting the limits
min_limit=Q1 - 1.5*IQR
print(min_limit)
max_limit=Q3 +1.5*IQR
print(max_limit)
# Out:
# 2.05
# 4.05

# %%
len(data.loc[data['SepalWidthCm'] < min_limit])
# Out:
# 1

# %%
len(data.loc[data['SepalWidthCm'] > max_limit])
# Out:
# 3

# %%
data.loc[data['SepalWidthCm'] > max_limit,'SepalWidthCm']=np.median(data.SepalWidthCm)

# %%
data.loc[data['SepalWidthCm'] < min_limit,'SepalWidthCm']=np.median(data.SepalWidthCm)

# %%
sns.boxplot(x=data['SepalWidthCm'])
plt.show()

# %%
#Step4 : Checking Duplicate data
data.duplicated().sum()
# Out:
# 0

# %%
#Step5 : Scaling Data
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]=scale.fit_transform(data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']])

# %% [markdown]
# ## Feature Selection

# %%
#Removing Unwanted/Constant Columns
l1=['Id']
data.drop(l1,axis=1,inplace=True)

# %%
#Finding Correlation
corr_data=data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
sns.heatmap(corr_data.corr(),annot=True)
plt.show()

# %% [markdown]
# ## Model Creation

# %%
X= data.iloc[:,:-1]
y= data['Species']

# %%
## Step 2 Creating training and testing data.
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=45)

# %%
y_test
# Out:
# 0      0
# 43     0
# 129    2
# 3      0
# 34     0
# 44     0
# 38     0
# 105    2
# 123    2
# 140    2
# 28     0
# 125    2
# 113    2
# 103    2
# 133    2
# 35     0
# 145    2
# 142    2
# 40     0
# 87     1
# 84     1
# 85     1
# 115    2
# 51     1
# 4      0
# 112    2
# 92     1
# 64     1
# 10     0
# 91     1
# 76     1
# 96     1
# 119    2
# 101    2
# 25     0
# 137    2
# 13     0
# 26     0
# Name: Species, dtype: int64

# %%
## Step 3 Model creation
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()
clf.fit(X_train,y_train)  ## training
# Out:
# LogisticRegression()

# %%
## Step 4 Prediction
y_pred= clf.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 2, 0, 0, 0, 0, 2, 2, 2, 0, 2, 2, 2, 1, 0, 2, 2, 0, 1, 1, 1,
#        2, 1, 0, 2, 1, 1, 0, 1, 1, 1, 1, 2, 0, 2, 0, 0])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score,classification_report,f1_score

# %%
# confusion matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[14  0  0]
#  [ 0  9  0]
#  [ 0  2 13]]

# %%
#recall score
recall=recall_score(y_test,y_pred,average='weighted')
recall
# Out:
# 0.9473684210526315

# %%
#f1 score
f1score=f1_score(y_test,y_pred,average='weighted')
f1score
# Out:
# 0.9481203007518798

# %%
#precision score
precision=precision_score(y_test,y_pred,average='weighted')
precision
# Out:
# 0.9569377990430621

# %%
#classificatio report
cr=classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.82      1.00      0.90         9
#            2       1.00      0.87      0.93        15
#
#     accuracy                           0.95        38
#    macro avg       0.94      0.96      0.94        38
# weighted avg       0.96      0.95      0.95        38
